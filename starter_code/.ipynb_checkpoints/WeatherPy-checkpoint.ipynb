# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
import api_keys


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#cities
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
api_key = api_keys.weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
#List of City data
#city_name = []
city_one=[]
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
count = 0
set = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        #city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        #city_record = response["name"]
            
       
        
        # Increase counter by one 
    
        if count > 50:
            count = 1
            set = set + 1
            city_one.append(city)
        else:
            count = count+1
            city_one.append(city)
        print(f"Processing Record {count} of Set {set} | {city}")
        print(f"{url}&q={city}")
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
print("------------------------------")
print("Data Retrievel Complete")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | moroni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=moroni
# City not found. Skipping...
# Processing Record 2 of Set 1 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=namatanai
# Processing Record 3 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=punta arenas
# Processing Record 4 of Set 1 | capilla de guadalupe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=capilla de guadalupe
# Processing Record 5 of Set 1 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hamilton
# Processing Record 6 of Set 1 | porterville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=porterville
# City not found. Skipping...
# Processing Record 7 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=provideniya
# Processing Record 8 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hilo
# Processing Record 9 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=port alfred
# Processing Record 10 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hermanus
# Processing Record 11 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=butaritari
# Processing Record 12 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=albany
# City not found. Skipping...
# Processing Record 13 of Set 1 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ancud
# Processing Record 14 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=georgetown
# Processing Record 15 of Set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=upernavik
# Processing Record 16 of Set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=lagoa
# Processing Record 17 of Set 1 | puerto carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=puerto carreno
# Processing Record 18 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=arraial do cabo
# Processing Record 19 of Set 1 | conceicao do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=conceicao do araguaia
# Processing Record 20 of Set 1 | yerofey pavlovich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=yerofey pavlovich
# Processing Record 21 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=east london
# Processing Record 22 of Set 1 | aksay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=aksay
# Processing Record 23 of Set 1 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tevaitoa
# Processing Record 24 of Set 1 | purpe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=purpe
# Processing Record 25 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ushuaia
# Processing Record 26 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=vaini
# Processing Record 27 of Set 1 | zunyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=zunyi
# Processing Record 28 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=fortuna
# Processing Record 29 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=thompson
# Processing Record 30 of Set 1 | minna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=minna
# Processing Record 31 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mataura
# Processing Record 32 of Set 1 | aneho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=aneho
# Processing Record 33 of Set 1 | bulungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bulungu
# City not found. Skipping...
# Processing Record 34 of Set 1 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dicabisagan
# City not found. Skipping...
# Processing Record 35 of Set 1 | perth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=perth
# Processing Record 36 of Set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hasaki
# Processing Record 37 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=severo-kurilsk
# City not found. Skipping...
# Processing Record 38 of Set 1 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=antalaha
# Processing Record 39 of Set 1 | anshun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=anshun
# Processing Record 40 of Set 1 | pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pathein
# Processing Record 41 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tasiilaq
# Processing Record 42 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=chuy
# Processing Record 43 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=avarua
# Processing Record 44 of Set 1 | shahapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=shahapur
# City not found. Skipping...
# Processing Record 45 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=torbay
# Processing Record 46 of Set 1 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=port hawkesbury
# Processing Record 47 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=yellowknife
# Processing Record 48 of Set 1 | kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kawalu
# Processing Record 49 of Set 1 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hami
# Processing Record 50 of Set 1 | gisborne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=gisborne
# Processing Record 51 of Set 1 | oussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=oussouye
# Processing Record 1 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=rikitea
# Processing Record 2 of Set 2 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=havoysund
# Processing Record 3 of Set 2 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kruisfontein
# Processing Record 4 of Set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hithadhoo
# Processing Record 5 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bredasdorp
# Processing Record 6 of Set 2 | kamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kamina
# Processing Record 7 of Set 2 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cabo san lucas
# Processing Record 8 of Set 2 | maxixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=maxixe
# Processing Record 9 of Set 2 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=geraldton
# Processing Record 10 of Set 2 | rosetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=rosetta
# Processing Record 11 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=busselton
# Processing Record 12 of Set 2 | buenaventura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=buenaventura
# Processing Record 13 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cape town
# Processing Record 14 of Set 2 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hovd
# Processing Record 15 of Set 2 | lubumbashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=lubumbashi
# Processing Record 16 of Set 2 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=praia da vitoria
# Processing Record 17 of Set 2 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=saldanha
# Processing Record 18 of Set 2 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=marzuq
# Processing Record 19 of Set 2 | imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=imbituba
# Processing Record 20 of Set 2 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ballina
# City not found. Skipping...
# Processing Record 21 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=talnakh
# Processing Record 22 of Set 2 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kaitangata
# Processing Record 23 of Set 2 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=zhigansk
# Processing Record 24 of Set 2 | fallon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=fallon
# Processing Record 25 of Set 2 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=vila franca do campo
# Processing Record 26 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kodiak
# Processing Record 27 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mahebourg
# Processing Record 28 of Set 2 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ixtapa
# Processing Record 29 of Set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=chokurdakh
# Processing Record 30 of Set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=airai
# Processing Record 31 of Set 2 | barguzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=barguzin
# Processing Record 32 of Set 2 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=souillac
# Processing Record 33 of Set 2 | loknya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=loknya
# Processing Record 34 of Set 2 | colon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=colon
# Processing Record 35 of Set 2 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kavaratti
# Processing Record 36 of Set 2 | mahalapye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mahalapye
# Processing Record 37 of Set 2 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nanortalik
# Processing Record 38 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mar del plata
# Processing Record 39 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kapaa
# Processing Record 40 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cidreira
# Processing Record 41 of Set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=iqaluit
# Processing Record 42 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=saskylakh
# Processing Record 43 of Set 2 | jiujiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=jiujiang
# Processing Record 44 of Set 2 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=salalah
# Processing Record 45 of Set 2 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=los llanos de aridane
# Processing Record 46 of Set 2 | larsnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=larsnes
# Processing Record 47 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=qaanaaq
# Processing Record 48 of Set 2 | jawhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=jawhar
# Processing Record 49 of Set 2 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=santa rosa
# Processing Record 50 of Set 2 | mwanza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mwanza
# Processing Record 51 of Set 2 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bambanglipuro
# Processing Record 1 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=lebu
# Processing Record 2 of Set 3 | ransang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ransang
# Processing Record 3 of Set 3 | sharan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sharan
# Processing Record 4 of Set 3 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=luderitz
# Processing Record 5 of Set 3 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=asau
# Processing Record 6 of Set 3 | cardonal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cardonal
# Processing Record 7 of Set 3 | togur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=togur
# Processing Record 8 of Set 3 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hobart
# Processing Record 9 of Set 3 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=huarmey
# Processing Record 10 of Set 3 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bilma
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 3 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=the valley
# Processing Record 12 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bambous virieux
# Processing Record 13 of Set 3 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bluff
# Processing Record 14 of Set 3 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=jamestown
# Processing Record 15 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=port elizabeth
# Processing Record 16 of Set 3 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=port-cartier
# Processing Record 17 of Set 3 | santa vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=santa vitoria
# Processing Record 18 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pisco
# Processing Record 19 of Set 3 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sao filipe
# Processing Record 20 of Set 3 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=coquimbo
# Processing Record 21 of Set 3 | sargur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sargur
# Processing Record 22 of Set 3 | san andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=san andres
# Processing Record 23 of Set 3 | yima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=yima
# City not found. Skipping...
# Processing Record 24 of Set 3 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=yulara
# Processing Record 25 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ribeira grande
# Processing Record 26 of Set 3 | khash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=khash
# Processing Record 27 of Set 3 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hervey bay
# City not found. Skipping...
# Processing Record 28 of Set 3 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=aksarka
# Processing Record 29 of Set 3 | podporozhye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=podporozhye
# Processing Record 30 of Set 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=puerto ayora
# Processing Record 31 of Set 3 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=klaksvik
# Processing Record 32 of Set 3 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=laguna
# Processing Record 33 of Set 3 | mmabatho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mmabatho
# Processing Record 34 of Set 3 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cherskiy
# Processing Record 35 of Set 3 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=zyryanka
# City not found. Skipping...
# Processing Record 36 of Set 3 | kitimat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kitimat
# Processing Record 37 of Set 3 | dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dali
# Processing Record 38 of Set 3 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=usinsk
# Processing Record 39 of Set 3 | yuci
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=yuci
# Processing Record 40 of Set 3 | rimbey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=rimbey
# Processing Record 41 of Set 3 | road town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=road town
# City not found. Skipping...
# Processing Record 42 of Set 3 | bonawon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bonawon
# Processing Record 43 of Set 3 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hofn
# Processing Record 44 of Set 3 | orlik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=orlik
# Processing Record 45 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=new norfolk
# Processing Record 46 of Set 3 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=esperance
# Processing Record 47 of Set 3 | balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=balkhash
# Processing Record 48 of Set 3 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=anadyr
# Processing Record 49 of Set 3 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=port blair
# Processing Record 50 of Set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=norman wells
# Processing Record 51 of Set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sitka
# Processing Record 1 of Set 4 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=inirida
# Processing Record 2 of Set 4 | guadix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=guadix
# Processing Record 3 of Set 4 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tiksi
# Processing Record 4 of Set 4 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=padang
# Processing Record 5 of Set 4 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nyurba
# Processing Record 6 of Set 4 | felipe carrillo puerto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=felipe carrillo puerto
# Processing Record 7 of Set 4 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=grindavik
# Processing Record 8 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nikolskoye
# Processing Record 9 of Set 4 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=muros
# Processing Record 10 of Set 4 | pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pundaguitan
# Processing Record 11 of Set 4 | suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=suntar
# Processing Record 12 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=codrington
# Processing Record 13 of Set 4 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=belmonte
# Processing Record 14 of Set 4 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nishihara
# Processing Record 15 of Set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=victoria
# Processing Record 16 of Set 4 | kabanjahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kabanjahe
# Processing Record 17 of Set 4 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=banda aceh
# Processing Record 18 of Set 4 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=rawson
# Processing Record 19 of Set 4 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bengkulu
# City not found. Skipping...
# Processing Record 20 of Set 4 | megalopoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=megalopoli
# City not found. Skipping...
# Processing Record 21 of Set 4 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=te anau
# Processing Record 22 of Set 4 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=vila velha
# Processing Record 23 of Set 4 | donskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=donskoye
# Processing Record 24 of Set 4 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dingle
# Processing Record 25 of Set 4 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nome
# City not found. Skipping...
# Processing Record 26 of Set 4 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=baruun-urt
# Processing Record 27 of Set 4 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=broken hill
# Processing Record 28 of Set 4 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=port hardy
# Processing Record 29 of Set 4 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ilhabela
# Processing Record 30 of Set 4 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=naze
# Processing Record 31 of Set 4 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=half moon bay
# Processing Record 32 of Set 4 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=barrow
# Processing Record 33 of Set 4 | roscommon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=roscommon
# Processing Record 34 of Set 4 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=necochea
# Processing Record 35 of Set 4 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=vao
# Processing Record 36 of Set 4 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=touros
# Processing Record 37 of Set 4 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=komsomolskiy
# Processing Record 38 of Set 4 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=havelock
# Processing Record 39 of Set 4 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=vestmannaeyjar
# Processing Record 40 of Set 4 | manicore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=manicore
# City not found. Skipping...
# Processing Record 41 of Set 4 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tuktoyaktuk
# Processing Record 42 of Set 4 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=labuhan
# Processing Record 43 of Set 4 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bethel
# Processing Record 44 of Set 4 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=krasnoselkup
# Processing Record 45 of Set 4 | pueblo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pueblo
# Processing Record 46 of Set 4 | lagoa vermelha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=lagoa vermelha
# Processing Record 47 of Set 4 | gander
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=gander
# Processing Record 48 of Set 4 | sarangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sarangani
# Processing Record 49 of Set 4 | izhma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=izhma
# Processing Record 50 of Set 4 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tuatapere
# Processing Record 51 of Set 4 | bakel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bakel
# Processing Record 1 of Set 5 | voi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=voi
# Processing Record 2 of Set 5 | brokopondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=brokopondo
# City not found. Skipping...
# Processing Record 3 of Set 5 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=lompoc
# Processing Record 4 of Set 5 | cao bang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cao bang
# Processing Record 5 of Set 5 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=la ronge
# Processing Record 6 of Set 5 | okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=okato
# Processing Record 7 of Set 5 | planaltina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=planaltina
# Processing Record 8 of Set 5 | charlestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=charlestown
# Processing Record 9 of Set 5 | cabay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cabay
# Processing Record 10 of Set 5 | torzhok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=torzhok
# Processing Record 11 of Set 5 | manuk mangkaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=manuk mangkaw
# Processing Record 12 of Set 5 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=inhambane
# City not found. Skipping...
# Processing Record 13 of Set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=faanui
# City not found. Skipping...
# Processing Record 14 of Set 5 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ilulissat
# Processing Record 15 of Set 5 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=carnarvon
# Processing Record 16 of Set 5 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=saint-pierre
# Processing Record 17 of Set 5 | dauriya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dauriya
# Processing Record 18 of Set 5 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=shingu
# Processing Record 19 of Set 5 | manica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=manica
# Processing Record 20 of Set 5 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nhulunbuy
# Processing Record 21 of Set 5 | joshimath
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=joshimath
# Processing Record 22 of Set 5 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=margate
# City not found. Skipping...
# Processing Record 23 of Set 5 | alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=alexandria
# Processing Record 24 of Set 5 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=isangel
# Processing Record 25 of Set 5 | vikhorevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=vikhorevka
# City not found. Skipping...
# Processing Record 26 of Set 5 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sao jose da coroa grande
# Processing Record 27 of Set 5 | san javier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=san javier
# Processing Record 28 of Set 5 | mineiros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mineiros
# Processing Record 29 of Set 5 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kutum
# Processing Record 30 of Set 5 | moree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=moree
# Processing Record 31 of Set 5 | rapar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=rapar
# Processing Record 32 of Set 5 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=jacareacanga
# Processing Record 33 of Set 5 | clyde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=clyde
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 5 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=fairbanks
# Processing Record 35 of Set 5 | pasni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pasni
# Processing Record 36 of Set 5 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=khatanga
# Processing Record 37 of Set 5 | san felix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=san felix
# Processing Record 38 of Set 5 | kota kinabalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kota kinabalu
# Processing Record 39 of Set 5 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=vanavara
# Processing Record 40 of Set 5 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bonthe
# Processing Record 41 of Set 5 | salaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=salaya
# Processing Record 42 of Set 5 | sidi ali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sidi ali
# Processing Record 43 of Set 5 | yermakovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=yermakovskoye
# Processing Record 44 of Set 5 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pacific grove
# Processing Record 45 of Set 5 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bandarbeyla
# Processing Record 46 of Set 5 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=emerald
# Processing Record 47 of Set 5 | jalingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=jalingo
# Processing Record 48 of Set 5 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mitu
# Processing Record 49 of Set 5 | sai buri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sai buri
# Processing Record 50 of Set 5 | talavera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=talavera
# Processing Record 51 of Set 5 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=broome
# Processing Record 1 of Set 6 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sinnamary
# Processing Record 2 of Set 6 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ponta do sol
# Processing Record 3 of Set 6 | miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=miri
# Processing Record 4 of Set 6 | dumingag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dumingag
# Processing Record 5 of Set 6 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=leningradskiy
# Processing Record 6 of Set 6 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=honiara
# Processing Record 7 of Set 6 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=clyde river
# Processing Record 8 of Set 6 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tezu
# Processing Record 9 of Set 6 | nkhotakota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nkhotakota
# Processing Record 10 of Set 6 | bargarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bargarh
# Processing Record 11 of Set 6 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=itarema
# Processing Record 12 of Set 6 | tukrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tukrah
# Processing Record 13 of Set 6 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hambantota
# Processing Record 14 of Set 6 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mount isa
# Processing Record 15 of Set 6 | bindura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bindura
# Processing Record 16 of Set 6 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mahibadhoo
# Processing Record 17 of Set 6 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=manokwari
# Processing Record 18 of Set 6 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=berlevag
# Processing Record 19 of Set 6 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=omsukchan
# Processing Record 20 of Set 6 | masuguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=masuguru
# Processing Record 21 of Set 6 | coxim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=coxim
# Processing Record 22 of Set 6 | sarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sarh
# City not found. Skipping...
# Processing Record 23 of Set 6 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=aklavik
# Processing Record 24 of Set 6 | santander
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=santander
# Processing Record 25 of Set 6 | boundiali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=boundiali
# Processing Record 26 of Set 6 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=caravelas
# Processing Record 27 of Set 6 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kavieng
# Processing Record 28 of Set 6 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=monrovia
# Processing Record 29 of Set 6 | qorveh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=qorveh
# Processing Record 30 of Set 6 | mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mehran
# Processing Record 31 of Set 6 | milton keynes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=milton keynes
# Processing Record 32 of Set 6 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=byron bay
# Processing Record 33 of Set 6 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=borogontsy
# Processing Record 34 of Set 6 | dekar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dekar
# Processing Record 35 of Set 6 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=fukue
# Processing Record 36 of Set 6 | tavda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tavda
# Processing Record 37 of Set 6 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=longyearbyen
# Processing Record 38 of Set 6 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=derzhavinsk
# Processing Record 39 of Set 6 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=atuona
# Processing Record 40 of Set 6 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=saint-philippe
# Processing Record 41 of Set 6 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=hualmay
# Processing Record 42 of Set 6 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dikson
# Processing Record 43 of Set 6 | campbell river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=campbell river
# Processing Record 44 of Set 6 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pangnirtung
# Processing Record 45 of Set 6 | yendi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=yendi
# Processing Record 46 of Set 6 | siirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=siirt
# Processing Record 47 of Set 6 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bathsheba
# Processing Record 48 of Set 6 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=axim
# Processing Record 49 of Set 6 | agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=agadez
# Processing Record 50 of Set 6 | timmendorfer strand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=timmendorfer strand
# Processing Record 51 of Set 6 | biloela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=biloela
# Processing Record 1 of Set 7 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=port hedland
# City not found. Skipping...
# Processing Record 2 of Set 7 | sechura
# ...
# Processing Record 12 of Set 10 | eregli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=eregli
# Processing Record 13 of Set 10 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=grand gaube
# Processing Record 14 of Set 10 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tautira
# Processing Record 15 of Set 10 | brooks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=brooks
# Processing Record 16 of Set 10 | fushun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=fushun
# Processing Record 17 of Set 10 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=gushikawa
# Processing Record 18 of Set 10 | kazan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kazan
# Processing Record 19 of Set 10 | gwadar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=gwadar
# Processing Record 20 of Set 10 | tobane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tobane
# Processing Record 21 of Set 10 | kyaikto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kyaikto
# Processing Record 22 of Set 10 | buckeye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=buckeye
# Processing Record 23 of Set 10 | ibra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ibra
# Processing Record 24 of Set 10 | dhone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dhone
# Processing Record 25 of Set 10 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=wahiawa
# Processing Record 26 of Set 10 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dunedin
# Processing Record 27 of Set 10 | ripoll
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ripoll
# Processing Record 28 of Set 10 | manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=manta
# Processing Record 29 of Set 10 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pochutla
# Processing Record 30 of Set 10 | dharchula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dharchula
# Processing Record 31 of Set 10 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=katsuura
# Processing Record 32 of Set 10 | adjuntas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=adjuntas
# City not found. Skipping...
# Processing Record 33 of Set 10 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=fare
# Processing Record 34 of Set 10 | la cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=la cruz
# Processing Record 35 of Set 10 | wairoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=wairoa
# City not found. Skipping...
# Processing Record 36 of Set 10 | tubuala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tubuala
# Processing Record 37 of Set 10 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cam ranh
# Processing Record 38 of Set 10 | nizhnetroitskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nizhnetroitskiy
# Processing Record 39 of Set 10 | miyako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=miyako
# Processing Record 40 of Set 10 | colesberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=colesberg
# Processing Record 41 of Set 10 | cliza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cliza
# Processing Record 42 of Set 10 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=amahai
# Processing Record 43 of Set 10 | maroantsetra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=maroantsetra
# Processing Record 44 of Set 10 | abong mbang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=abong mbang
# Processing Record 45 of Set 10 | quang ngai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=quang ngai
# Processing Record 46 of Set 10 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=camacha
# Processing Record 47 of Set 10 | port hueneme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=port hueneme
# Processing Record 48 of Set 10 | mongoumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mongoumba
# Processing Record 49 of Set 10 | chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=chimbote
# Processing Record 50 of Set 10 | ercis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ercis
# Processing Record 51 of Set 10 | otjimbingwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=otjimbingwe
# City not found. Skipping...
# Processing Record 1 of Set 11 | duldurga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=duldurga
# City not found. Skipping...
# Processing Record 2 of Set 11 | buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=buin
# City not found. Skipping...
# Processing Record 3 of Set 11 | asasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=asasa
# Processing Record 4 of Set 11 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mount gambier
# Processing Record 5 of Set 11 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ranong
# Processing Record 6 of Set 11 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=coihaique
# Processing Record 7 of Set 11 | saint-denis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=saint-denis
# Processing Record 8 of Set 11 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=haines junction
# Processing Record 9 of Set 11 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=gizo
# Processing Record 10 of Set 11 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cayenne
# Processing Record 11 of Set 11 | barcelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=barcelos
# Processing Record 12 of Set 11 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=svetlaya
# Processing Record 13 of Set 11 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=faya
# Processing Record 14 of Set 11 | labuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=labuan
# Processing Record 15 of Set 11 | la libertad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=la libertad
# City not found. Skipping...
# Processing Record 16 of Set 11 | pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pangai
# Processing Record 17 of Set 11 | monte alegre de minas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=monte alegre de minas
# City not found. Skipping...
# Processing Record 18 of Set 11 | el alto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=el alto
# Processing Record 19 of Set 11 | antonina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=antonina
# Processing Record 20 of Set 11 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=mareeba
# Processing Record 21 of Set 11 | tierranueva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=tierranueva
# Processing Record 22 of Set 11 | brigantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=brigantine
# Processing Record 23 of Set 11 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nantucket
# City not found. Skipping...
# Processing Record 24 of Set 11 | rumphi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=rumphi
# Processing Record 25 of Set 11 | antsohihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=antsohihy
# City not found. Skipping...
# Processing Record 26 of Set 11 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ulladulla
# Processing Record 27 of Set 11 | ariquemes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ariquemes
# Processing Record 28 of Set 11 | palanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=palanga
# Processing Record 29 of Set 11 | alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=alihe
# Processing Record 30 of Set 11 | auriflama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=auriflama
# Processing Record 31 of Set 11 | cardedeu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cardedeu
# Processing Record 32 of Set 11 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ornskoldsvik
# Processing Record 33 of Set 11 | isabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=isabela
# Processing Record 34 of Set 11 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=palmer
# Processing Record 35 of Set 11 | san pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=san pedro
# Processing Record 36 of Set 11 | sakaraha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=sakaraha
# Processing Record 37 of Set 11 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=zhanaozen
# Processing Record 38 of Set 11 | pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=pierre
# Processing Record 39 of Set 11 | roura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=roura
# Processing Record 40 of Set 11 | magnitogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=magnitogorsk
# Processing Record 41 of Set 11 | menongue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=menongue
# Processing Record 42 of Set 11 | cravo norte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=cravo norte
# Processing Record 43 of Set 11 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=xining
# Processing Record 44 of Set 11 | gaoyou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=gaoyou
# Processing Record 45 of Set 11 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ostrovnoy
# Processing Record 46 of Set 11 | zhenhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=zhenhai
# Processing Record 47 of Set 11 | porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=porbandar
# Processing Record 48 of Set 11 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=atar
# Processing Record 49 of Set 11 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=petropavlovsk-kamchatskiy
# Processing Record 50 of Set 11 | bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=bontang
# Processing Record 51 of Set 11 | nueva italia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=nueva italia
# City not found. Skipping...
# Processing Record 1 of Set 12 | dolinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dolinsk
# Processing Record 2 of Set 12 | dehui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=dehui
# Processing Record 3 of Set 12 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=peniche
# Processing Record 4 of Set 12 | kusti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kusti
# Processing Record 5 of Set 12 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kalmunai
# Processing Record 6 of Set 12 | chkalovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=chkalovskoye
# Processing Record 7 of Set 12 | petropavlivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=petropavlivka
# Processing Record 8 of Set 12 | manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=manado
# Processing Record 9 of Set 12 | kondinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=kondinskoye
# Processing Record 10 of Set 12 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c22bf926a8a243113e8815af211b8049&q=ketchikan
# ------------------------------
# Data Retrievel Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather = {
    "City": city_one,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}
data= pd.DataFrame(weather)
data.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Save data frame to CSV
data.to_csv('../Output/data.csv')

# Display data frame head 
data.head()
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                moroni -11.70   43.26     77.63        73          26
# 1             namatanai  -3.67  152.43     79.84        81           2
# 2          punta arenas -53.15  -70.92     41.00        86          75
# 3  capilla de guadalupe  20.83 -102.58     77.05        19           0
# 4              hamilton  39.18  -84.53     75.99        78          90
#
#    Wind Speed Country        Date
# 0       18.66      KM  1589651582
# 1        6.67      PG  1589651582
# 2        5.82      CL  1589651268
# 3       11.07      MX  1589651583
# 4        6.82      US  1589651583

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
data['Humidity'] > 100
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 566    False
# 567    False
# 568    False
# 569    False
# 570    False
# Name: Humidity, Length: 571, dtype: bool

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(data["Lat"], data["Max Temp"], marker='o', s=30)

plt.xlabel('Latitude')
plt.ylabel('Max Temerature(F)')
plt.title('City Latitude vs Max Temperature')
plt.grid()

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(data['Lat'], data['Humidity'], marker='o', s=30)
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs. Humidity')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(data['Lat'], data['Cloudiness'], marker='o', s=30)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs. Cloudiness')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(data['Lat'], data['Wind Speed'], marker='o', s=30)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed')
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = data.loc[data["Lat"]>0.01]
southern_hemisphere = data.loc[data["Lat"]<-0.01]

northern_hemisphere.head()
#southern_hemisphere.head()
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 3  capilla de guadalupe  20.83 -102.58     77.05        19           0
# 4              hamilton  39.18  -84.53     75.99        78          90
# 5           porterville  36.07 -119.02     75.00        49           1
# 6           provideniya  64.38 -173.30     40.35        66          19
# 7                  hilo  19.73 -155.09     75.99        69          90
#
#    Wind Speed Country        Date
# 3       11.07      MX  1589651583
# 4        6.82      US  1589651583
# 5        4.70      US  1589651583
# 6       10.87      RU  1589651583
# 7        5.82      US  1589651262

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.777364315212719

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5450724678190066

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.01535911334595655

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.01667250346659467

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.029297336284019235

# %%
# Out:
# The r-squared is: 0.05768812657005063

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04003104952596548

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0015034193196962959

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00360705038416173
